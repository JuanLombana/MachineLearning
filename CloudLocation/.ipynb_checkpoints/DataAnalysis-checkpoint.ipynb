# %%
import pandas as pd
import numpy as np
import json
import math
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Lectura de Archivos y Carga de Datos

# %%
folders = ('01-10-19_PT5M','02-10-19_PT5M','05-10-19_PT5M','08-10-19_PT5M')
assets = pd.read_csv('southcentral-asset.csv',sep=';')
assets.sample(5)
# Out:
#       ResourceGruop             Name  Nodes            Size      Tier  \
# 52     webflowersVL     webflowersVL      2  Standard_A1_v2  Standard
# 4     WebFlowersBQC    WebFlowersBQC      2  Standard_A1_v2  Standard
# 41     WebFlowersQF     WebFlowersQF      2  Standard_A1_v2  Standard
# 9   WebFlowersDCCNM  WebFlowersDCCNM      2  Standard_A1_v2  Standard
# 2      WebFlowersAL     WebFlowersAL      2  Standard_A1_v2  Standard
#
#                            File
# 52     webflowersVLresults.json
# 4     WebFlowersBQCresults.json
# 41     WebFlowersQFresults.json
# 9   WebFlowersDCCNMresults.json
# 2      WebFlowersALresults.json

# %% [markdown]
# Recorrer el inventario y cargarlos datos en los arreglos respectivos

# %%
datosCPU={}
datosNTI={}
datosNTO={}

for i,r in assets.iterrows():
    print(r.Name)
    ultimoMin = 0
    for j in np.arange(0,len(folders)):
        with open(folders[j]+'/'+r.File, 'r') as f:
            datastore = json.load(f)
            print('File readed:'+folders[j]+'/'+r.File)
        tempCPU = pd.DataFrame(datastore["value"][0]["metricValues"])
        tempNTI = pd.DataFrame(datastore["value"][1]["metricValues"])
        tempNTO = pd.DataFrame(datastore["value"][2]["metricValues"])
        tempMin = np.arange(ultimoMin,ultimoMin+(tempCPU.shape[0]*5),step=5)
        tempCPU['minute'] = tempMin
        tempNTI['minute'] = tempMin
        tempNTO['minute'] = tempMin
        ultimoMin = tempMin[len(tempMin)-1]+5
        print(ultimoMin)
        tempCPU = tempCPU.dropna(axis=0,how='any')
        tempNTI = tempNTI.dropna(axis=0,how='any')
        tempNTO = tempNTO.dropna(axis=0,how='any')
        if r.Name in datosCPU:
            datosCPU[r.Name] = datosCPU[r.Name].append(tempCPU)
            datosNTI[r.Name] = datosNTI[r.Name].append(tempNTI)
            datosNTO[r.Name] = datosNTO[r.Name].append(tempNTO)
        else:
            datosCPU[r.Name] = tempCPU
            datosNTI[r.Name] = tempNTI
            datosNTO[r.Name] = tempNTO
# Out:
# WebFlowersPA
# File readed:01-10-19_PT5M/WebFlowersPAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersPAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersPAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersPAresults.json
# 13500
# WebflowersIC
# File readed:01-10-19_PT5M/WebflowersICresults.json
# 540
# File readed:02-10-19_PT5M/WebflowersICresults.json
# 4860
# File readed:05-10-19_PT5M/WebflowersICresults.json
# 9180
# File readed:08-10-19_PT5M/WebflowersICresults.json
# 13500
# WebFlowersAL
# File readed:01-10-19_PT5M/WebFlowersALresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersALresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersALresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersALresults.json
# 13500
# WebFlowersBGSales
# File readed:01-10-19_PT5M/WebFlowersBGSalesresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersBGSalesresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersBGSalesresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersBGSalesresults.json
# 13500
# WebFlowersBQC
# File readed:01-10-19_PT5M/WebFlowersBQCresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersBQCresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersBQCresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersBQCresults.json
# 13500
# WebFlowersCA
# File readed:01-10-19_PT5M/WebFlowersCAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersCAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersCAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersCAresults.json
# 13500
# WebFlowersCH
# File readed:01-10-19_PT5M/WebFlowersCHresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersCHresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersCHresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersCHresults.json
# 13500
# WebFlowersCP
# File readed:01-10-19_PT5M/WebFlowersCPresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersCPresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersCPresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersCPresults.json
# 13500
# WebFlowersCQ
# File readed:01-10-19_PT5M/WebFlowersCQresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersCQresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersCQresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersCQresults.json
# 13500
# WebFlowersDCCNM
# File readed:01-10-19_PT5M/WebFlowersDCCNMresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersDCCNMresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersDCCNMresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersDCCNMresults.json
# 13500
# WebFlowersDCNM
# File readed:01-10-19_PT5M/WebFlowersDCNMresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersDCNMresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersDCNMresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersDCNMresults.json
# 13500
# WebFlowersDPANM
# File readed:01-10-19_PT5M/WebFlowersDPANMresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersDPANMresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersDPANMresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersDPANMresults.json
# 13500
# WebFlowersER
# File readed:01-10-19_PT5M/WebFlowersERresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersERresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersERresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersERresults.json
# 13500
# WebFlowersFA
# File readed:01-10-19_PT5M/WebFlowersFAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFAresults.json
# 13500
# WebFlowersFD
# File readed:01-10-19_PT5M/WebFlowersFDresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFDresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFDresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFDresults.json
# 13500
# WebFlowersFE
# File readed:01-10-19_PT5M/WebFlowersFEresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFEresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFEresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFEresults.json
# 13500
# WebFlowersFG
# File readed:01-10-19_PT5M/WebFlowersFGresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFGresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFGresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFGresults.json
# 13500
# WebFlowersFL
# File readed:01-10-19_PT5M/WebFlowersFLresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFLresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFLresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFLresults.json
# 13500
# WebFlowersFV
# File readed:01-10-19_PT5M/WebFlowersFVresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersFVresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersFVresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersFVresults.json
# 13500
# webflowersfxsales
# File readed:01-10-19_PT5M/webflowersfxsalesresults.json
# 540
# File readed:02-10-19_PT5M/webflowersfxsalesresults.json
# 4860
# File readed:05-10-19_PT5M/webflowersfxsalesresults.json
# 9180
# File readed:08-10-19_PT5M/webflowersfxsalesresults.json
# 13500
# WebFlowersGOSALES
# File readed:01-10-19_PT5M/WebFlowersGOSALESresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersGOSALESresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersGOSALESresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersGOSALESresults.json
# 13500
# WebFlowersGrChia
# File readed:01-10-19_PT5M/WebFlowersGrChiaresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersGrChiaresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersGrChiaresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersGrChiaresults.json
# 13500
# WebFlowersHT
# File readed:01-10-19_PT5M/WebFlowersHTresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersHTresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersHTresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersHTresults.json
# 13500
# WebFlowersIB
# File readed:01-10-19_PT5M/WebFlowersIBresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersIBresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersIBresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersIBresults.json
# 13500
# WebFlowersJA
# File readed:01-10-19_PT5M/WebFlowersJAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersJAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersJAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersJAresults.json
# 13500
# WebFlowersJN
# File readed:01-10-19_PT5M/WebFlowersJNresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersJNresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersJNresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersJNresults.json
# 13500
# WebFlowersJP
# File readed:01-10-19_PT5M/WebFlowersJPresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersJPresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersJPresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersJPresults.json
# 13500
# WebFlowersJQ
# File readed:01-10-19_PT5M/WebFlowersJQresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersJQresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersJQresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersJQresults.json
# 13500
# WebFlowersJU
# File readed:01-10-19_PT5M/WebFlowersJUresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersJUresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersJUresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersJUresults.json
# 13500
# WebFlowersLA
# File readed:01-10-19_PT5M/WebFlowersLAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersLAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersLAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersLAresults.json
# 13500
# WebFlowersLC
# File readed:01-10-19_PT5M/WebFlowersLCresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersLCresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersLCresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersLCresults.json
# 13500
# WebFlowersLM
# File readed:01-10-19_PT5M/WebFlowersLMresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersLMresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersLMresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersLMresults.json
# 13500
# WebFlowersLogisticServices
# File readed:01-10-19_PT5M/WebFlowersLogisticServicesresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersLogisticServicesresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersLogisticServicesresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersLogisticServicesresults.json
# 13500
# WebFlowersLV
# File readed:01-10-19_PT5M/WebFlowersLVresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersLVresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersLVresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersLVresults.json
# 13500
# WebFlowersMG
# File readed:01-10-19_PT5M/WebFlowersMGresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersMGresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersMGresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersMGresults.json
# 13500
# WebFlowersML
# File readed:01-10-19_PT5M/WebFlowersMLresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersMLresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersMLresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersMLresults.json
# 13500
# WebFlowersMO
# File readed:01-10-19_PT5M/WebFlowersMOresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersMOresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersMOresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersMOresults.json
# 13500
# WebFlowersOL
# File readed:01-10-19_PT5M/WebFlowersOLresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersOLresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersOLresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersOLresults.json
# 13500
# WebFlowersPL
# File readed:01-10-19_PT5M/WebFlowersPLresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersPLresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersPLresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersPLresults.json
# 13500
# webflowersproductcentral
# File readed:01-10-19_PT5M/webflowersproductcentralresults.json
# 540
# File readed:02-10-19_PT5M/webflowersproductcentralresults.json
# 4860
# File readed:05-10-19_PT5M/webflowersproductcentralresults.json
# 9180
# File readed:08-10-19_PT5M/webflowersproductcentralresults.json
# 13500
# WebFlowersQA
# File readed:01-10-19_PT5M/WebFlowersQAresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersQAresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersQAresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersQAresults.json
# 13500
# WebFlowersQF
# File readed:01-10-19_PT5M/WebFlowersQFresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersQFresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersQFresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersQFresults.json
# 13500
# WebFlowersQueensSales
# File readed:01-10-19_PT5M/WebFlowersQueensSalesresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersQueensSalesresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersQueensSalesresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersQueensSalesresults.json
# 13500
# WebFlowersRF
# File readed:01-10-19_PT5M/WebFlowersRFresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersRFresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersRFresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersRFresults.json
# 13500
# WebFlowersRQ
# File readed:01-10-19_PT5M/WebFlowersRQresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersRQresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersRQresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersRQresults.json
# 13500
# WebFlowersSB
# File readed:01-10-19_PT5M/WebFlowersSBresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersSBresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersSBresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersSBresults.json
# 13500
# WebFlowersSC
# File readed:01-10-19_PT5M/WebFlowersSCresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersSCresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersSCresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersSCresults.json
# 13500
# WebFlowersSN
# File readed:01-10-19_PT5M/WebFlowersSNresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersSNresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersSNresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersSNresults.json
# 13500
# WebFlowersSZ
# File readed:01-10-19_PT5M/WebFlowersSZresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersSZresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersSZresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersSZresults.json
# 13500
# WebFlowersTN
# File readed:01-10-19_PT5M/WebFlowersTNresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersTNresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersTNresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersTNresults.json
# 13500
# WebFlowersTR
# File readed:01-10-19_PT5M/WebFlowersTRresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersTRresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersTRresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersTRresults.json
# 13500
# WebFlowersUB
# File readed:01-10-19_PT5M/WebFlowersUBresults.json
# 540
# File readed:02-10-19_PT5M/WebFlowersUBresults.json
# 4860
# File readed:05-10-19_PT5M/WebFlowersUBresults.json
# 9180
# File readed:08-10-19_PT5M/WebFlowersUBresults.json
# 13500
# webflowersVL
# File readed:01-10-19_PT5M/webflowersVLresults.json
# 540
# File readed:02-10-19_PT5M/webflowersVLresults.json
# 4860
# File readed:05-10-19_PT5M/webflowersVLresults.json
# 9180
# File readed:08-10-19_PT5M/webflowersVLresults.json
# 13500

# %%
accumNTO={}
for i,r in assets.iterrows():
    for d in np.arange(1,11):
        temp = datosNTO[r.Name][(datosNTO[r.Name]['minute'] >= ((d-1)*1440)) & (datosNTO[r.Name]['minute'] < (d*1440))]
        sumx = temp.apply(np.sum,axis= 0)
        accumNTO[str(d)+'-'+r.Name] =pd.DataFrame(sumx[1:5])

# %%
tempCPU_1 = datosCPU['WebFlowersLM']
tempCPU_2 = datosCPU['WebFlowersCA']

# %% [markdown]
# ## CPU vs Tiempo en Máximos, Promedios, Mínimos y Acumulados cada 5 Minutos

# %%
fig, (ax1,ax2,ax3,ax4)=plt.subplots(4,1,figsize=(20,8))
ax1.set_ylabel('MAX')
ax1.plot(tempCPU_1['minute'], tempCPU_1['maximum'], color = 'red', label='CPU1')
ax1.plot(tempCPU_2['minute'], tempCPU_2['maximum'], color = 'blue', label='CPU2')
ax1.grid(True)
ax2.set_ylabel('AVG')
ax2.plot(tempCPU_2['minute'], tempCPU_2['average'], color = 'blue', label='CPU2')
ax2.plot(tempCPU_1['minute'], tempCPU_1['average'], color = 'red', label='CPU1')
ax2.grid(True)
ax3.set_ylabel('MIN')
ax3.plot(tempCPU_1['minute'], tempCPU_1['minimum'], color = 'red', label='CPU1')
ax3.plot(tempCPU_2['minute'], tempCPU_2['minimum'], color = 'blue', label='CPU2')
ax3.grid(True)
ax4.set_ylabel('SUM')
ax4.plot(tempCPU_1['minute'], tempCPU_1['total'], color = 'red', label='CPU1')
ax4.plot(tempCPU_2['minute'], tempCPU_2['total'], color = 'blue', label='CPU2')
ax4.grid(True)
ax3.set_xlabel('Minutos')
# Out:
# Text(0.5, 0, 'Minutos')

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,8))
ax1.boxplot([tempCPU_1['maximum'],tempCPU_2['maximum']])
ax2.boxplot([tempCPU_1['average'],tempCPU_2['average']])
ax3.boxplot([tempCPU_1['minimum'],tempCPU_2['minimum']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ad24708b48>,
#   <matplotlib.lines.Line2D at 0x1ad2475fb08>,
#   <matplotlib.lines.Line2D at 0x1ad24766dc8>,
#   <matplotlib.lines.Line2D at 0x1ad2476c308>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ad24762b88>,
#   <matplotlib.lines.Line2D at 0x1ad2475f748>,
#   <matplotlib.lines.Line2D at 0x1ad24775088>,
#   <matplotlib.lines.Line2D at 0x1ad24775c08>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ad24708d08>,
#   <matplotlib.lines.Line2D at 0x1ad24766908>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ad24762ac8>,
#   <matplotlib.lines.Line2D at 0x1ad24775988>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ad247623c8>,
#   <matplotlib.lines.Line2D at 0x1ad2477b148>],
#  'means': []}

# %% [markdown]
# ## Entrada de RED vs Tiempo en Máximos, Promedios y Mínimos cada 5 Minutos

# %%
tempNTI_1 = datosNTI['WebFlowersLM']
tempNTI_2 = datosNTI['WebFlowersCA']

# %%
fig, (ax1,ax2,ax3)=plt.subplots(3,1,figsize=(20,8))
ax1.set_ylabel('MAX')
ax1.plot(tempNTI_1['minute'], tempNTI_1['maximum']/(math.pow(1024,2)), color = 'red', label='CPU1')
ax1.plot(tempNTI_2['minute'], tempNTI_2['maximum']/(math.pow(1024,2)), color = 'blue', label='CPU2')
ax1.grid(True)
ax2.set_ylabel('AVG')
ax2.plot(tempNTI_1['minute'], tempNTI_1['average']/(math.pow(1024,2)), color = 'red', label='CPU1')
ax2.plot(tempNTI_2['minute'], tempNTI_2['average']/(math.pow(1024,2)), color = 'blue', label='CPU2')
ax2.grid(True)
ax3.set_ylabel('MIN')
ax3.plot(tempNTI_1['minute'], tempNTI_1['minimum']/(math.pow(1024,2)), color = 'red', label='CPU1')
ax3.plot(tempNTI_2['minute'], tempNTI_2['minimum']/(math.pow(1024,2)), color = 'blue', label='CPU2')
ax3.grid(True)
ax3.set_xlabel('Minutos')
# Out:
# Text(0.5, 0, 'Minutos')

# %% [markdown]
# ## Salida de RED vs Tiempo en Máximos, Promedios y Mínimos cada 5 Minutos

# %%
tempNTO_1 = datosNTO['WebFlowersLM']
tempNTO_2 = datosNTO['WebFlowersCA']

# %%
fig, (ax1,ax2,ax3)=plt.subplots(3,1,figsize=(20,8))
ax1.set_ylabel('MAX')
ax1.plot(tempNTO_1['minute'], tempNTO_1['maximum'], color = 'red', label='CPU1')
ax1.plot(tempNTO_2['minute'], tempNTO_2['maximum'], color = 'blue', label='CPU2')
ax1.grid(True)
ax2.set_ylabel('AVG')
ax2.plot(tempNTO_1['minute'], tempNTO_1['average']/(math.pow(1024,2)), color = 'red', label='CPU1')
ax2.plot(tempNTO_2['minute'], tempNTO_2['average']/(math.pow(1024,2)), color = 'blue', label='CPU2')
ax2.grid(True)
ax3.set_ylabel('MIN')
ax3.plot(tempNTO_1['minute'], tempNTO_1['minimum']/(math.pow(1024,2)), color = 'red', label='CPU1')
ax3.plot(tempNTO_2['minute'], tempNTO_2['minimum']/(math.pow(1024,2)), color = 'blue', label='CPU2')
ax3.grid(True)
ax3.set_xlabel('Minutos');

# %%
def obtenerDatosAcumulados(nombreEmpresa):
    total = np.array([[1,accumNTO['1-'+nombreEmpresa].transpose()['total'][0]]])
    total = np.append(total, [[2,accumNTO['2-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[3,accumNTO['3-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[4,accumNTO['4-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[5,accumNTO['5-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[6,accumNTO['6-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[7,accumNTO['7-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[8,accumNTO['8-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[9,accumNTO['9-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    total = np.append(total, [[10,accumNTO['10-'+nombreEmpresa].transpose()['total'][0]]],axis=0)
    acumm = pd.DataFrame(total,columns=['dia','acumulado'])
    acumm.dropna(axis=0,how='any')
    return acumm

# %%
plt.figure(figsize=(20,8))
for i in np.arange(0,10):
    company = assets.Name[i]
    Acumm = obtenerDatosAcumulados(company)
    plt.plot(Acumm['dia'], Acumm['acumulado']/(math.pow(1024,2)), label=company)
plt.legend();

# %%
Acumm1=obtenerDatosAcumulados('WebFlowersLM')
Acumm2=obtenerDatosAcumulados('WebFlowersBQC')
Acumm3=obtenerDatosAcumulados('WebFlowersQueensSales')
Acumm4=obtenerDatosAcumulados('WebFlowersCA')
Acumm5=obtenerDatosAcumulados('WebFlowersTR')
Acumm6=obtenerDatosAcumulados('WebFlowersFE')
plt.figure(figsize=(20,8))

plt.plot(Acumm2['dia'], Acumm2['acumulado']/(math.pow(1024,2)), label='BQC')
plt.plot(Acumm3['dia'], Acumm3['acumulado']/(math.pow(1024,2)), label='QueensSales')

plt.plot(Acumm1['dia'], Acumm1['acumulado']/(math.pow(1024,2)), label='LM')
plt.plot(Acumm6['dia'], Acumm6['acumulado']/(math.pow(1024,2)), label='FE')

plt.plot(Acumm4['dia'], Acumm4['acumulado']/(math.pow(1024,2)), label='CA')
plt.plot(Acumm5['dia'], Acumm5['acumulado']/(math.pow(1024,2)), label='TR')
#plt.ylim(0,800)
plt.legend();

# %%
plt.boxplot([Acumm1['acumulado'],Acumm6['acumulado'],Acumm4['acumulado']]);

# %%
plt.boxplot([Acumm5['acumulado']]);

# %%
Acumm2
# Out:
#     dia     acumulado
# 0   1.0           NaN
# 1   2.0           NaN
# 2   3.0  1.400059e+09
# 3   4.0  2.099023e+09
# 4   5.0  6.921590e+08
# 5   6.0  1.583752e+09
# 6   7.0  2.453262e+09
# 7   8.0  3.057712e+09
# 8   9.0  3.271425e+09
# 9  10.0  2.203133e+09

# %%
a = [ np.random.uniform(size=100),np.random.normal(size=100),np.random.exponential(size=100)]
plt.boxplot(a);

# %%
plt.plot(a[0])
plt.plot(a[1])
plt.plot(a[2]);

# %%
sns.distplot(a[0]);

# %%
sns.distplot(a[1]);

# %%
sns.distplot(a[2]);
